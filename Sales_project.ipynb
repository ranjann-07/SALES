# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Sales_April_2019.csv")
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
df.head(20)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 1       NaN                         NaN              NaN        NaN
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# 5    176561            Wired Headphones                1      11.99
# 6    176562        USB-C Charging Cable                1      11.95
# 7    176563  Bose SoundSport Headphones                1      99.99
# 8    176564        USB-C Charging Cable                1      11.95
# 9    176565          Macbook Pro Laptop                1       1700
# 10   176566            Wired Headphones                1      11.99
# 11   176567                Google Phone                1        600
# 12   176568    Lightning Charging Cable                1      14.95
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %%
df.tail(2015)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 16368   192174          Wired Headphones                1      11.99
# 16369   192175          Wired Headphones                1      11.99
# 16370   192176    AAA Batteries (4-pack)                3       2.99
# 16371   192177          Wired Headphones                1      11.99
# 16372   192178      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 16368  04/29/19 19:06       697 Wilson St, Portland, ME 04101
# ...

# %%
df.describe()
# Out:
#         Order ID                   Product Quantity Ordered Price Each  \
# count      18324                     18324            18324      18324
# unique     17538                        20                8         19
# top     Order ID  Lightning Charging Cable                1      14.95
# freq          35                      2201            16558       2201
#
#         Order Date  Purchase Address
# count        18324             18324
# unique       13584             17120
# top     Order Date  Purchase Address
# freq            35                35

# %%
df.shape
# Out:
# (18383, 6)

# %%
df.isna().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address    59
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    18268
# True        56
# Name: count, dtype: int64

# %%
dfa=df.drop_duplicates (subset=None, keep="first", inplace=False)
dfa
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
dfa.columns=["order_ID" , "Product" , "Quantity_Ordered" , "Price_Each" , "Order_Date" , "Purchase_Address"]
dfa.head()
# Out:
#   order_ID                     Product Quantity_Ordered Price_Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order_Date                      Purchase_Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
dfa["Date"]= dfa["Order_Date"].str[:8]
dfa
# Out:
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/481771716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa["Date"]= dfa["Order_Date"].str[:8]
#       order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# ...

# %%
dfa["Month"]= dfa["Order_Date"].str[:2]
dfa
# Out:
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/3557818100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa["Month"]= dfa["Order_Date"].str[:2]
#       order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# ...

# %%
dfa[["House_No" ,"City", "Pin_Code"]]= dfa.Purchase_Address.str.split(",",expand=True)
dfa
# Out:
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/2138275889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa[["House_No" ,"City", "Pin_Code"]]= dfa.Purchase_Address.str.split(",",expand=True)
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/2138275889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa[["House_No" ,"City", "Pin_Code"]]= dfa.Purchase_Address.str.split(",",expand=True)
# ...

# %%
dfa.Month.value_counts()
# Out:
# Month
# 04    18239
# 05       28
# Or        1
# Name: count, dtype: int64

# %%
dfa = dfa[dfa['Month']!='Or']
dfa.head()
# Out:
#   order_ID                     Product Quantity_Ordered Price_Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order_Date                      Purchase_Address      Date Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001  04/19/19    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215  04/07/19    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001  04/30/19    04
#
#           House_No          City   Pin_Code
# 0       917 1st St        Dallas   TX 75001
# ...

# %%
dfa['Month'] = dfa['Month'].astype('int64')
dfa['Order_Date'] = pd.to_datetime(dfa['Order_Date'])
dfa['Date'] = pd.to_datetime(dfa['Date'])
dfa.info()
# Out:
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/1647446278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Month'] = dfa['Month'].astype('int64')
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/1647446278.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dfa['Order_Date'] = pd.to_datetime(dfa['Order_Date'])
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
# ...

# %%
dfa['Month'] = dfa['Month'].astype('int64')
dfa['Order_Date'] = pd.to_datetime(dfa['Order_Date'])
dfa['Date'] = pd.to_datetime(dfa['Date'])
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_ID          18267 non-null  object
#  1   Product           18267 non-null  object
#  2   Quantity_Ordered  18267 non-null  object
#  3   Price_Each        18267 non-null  object
#  4   Order_Date        18267 non-null  datetime64[ns]
#  5   Purchase_Address  18267 non-null  object
#  6   Date              18267 non-null  datetime64[ns]
#  7   Month             18267 non-null  int64
#  8   House_No          18267 non-null  object
#  9   City              18267 non-null  object
#  10  Pin_Code          18267 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(8)
# memory usage: 1.7+ MB
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/1647446278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfa.order_ID.value_counts()
# Out:
# order_ID
# 193511    4
# 177167    3
# 191433    3
# 183436    3
# 181177    3
#          ..
# 182519    1
# 182520    1
# 182521    1
# 182522    1
# 194094    1
# Name: count, Length: 17537, dtype: int64

# %%
dfa.Quantity_Ordered.value_counts()
# Out:
# Quantity_Ordered
# 1    16536
# 2     1328
# 3      299
# 4       72
# 5       24
# 6        7
# 7        1
# Name: count, dtype: int64

# %%
dfa[ 'Quantity_ordered']= dfa['Quantity_Ordered'].astype('int32')
dfa['Price_Each']= dfa['Price_Each'].astype("float64")
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_ID          18267 non-null  object
#  1   Product           18267 non-null  object
#  2   Quantity_Ordered  18267 non-null  object
#  3   Price_Each        18267 non-null  float64
#  4   Order_Date        18267 non-null  datetime64[ns]
#  5   Purchase_Address  18267 non-null  object
#  6   Date              18267 non-null  datetime64[ns]
#  7   Month             18267 non-null  int64
#  8   House_No          18267 non-null  object
#  9   City              18267 non-null  object
#  10  Pin_Code          18267 non-null  object
#  11  Quantity_ordered  18267 non-null  int32
# dtypes: datetime64[ns](2), float64(1), int32(1), int64(1), object(7)
# memory usage: 1.7+ MB
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/2042857336.py:1: SettingWithCopyWarning:
# ...

# %%
dfa['Sales']= dfa['Quantity_ordered']* dfa['Price_Each']
dfa
# Out:
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/3774186923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Sales']= dfa['Quantity_ordered']* dfa['Price_Each']
#       order_ID                     Product Quantity_Ordered  Price_Each  \
# 0       176558        USB-C Charging Cable                2       11.95
# 2       176559  Bose SoundSport Headphones                1       99.99
# 3       176560                Google Phone                1      600.00
# 4       176560            Wired Headphones                1       11.99
# 5       176561            Wired Headphones                1       11.99
# ...        ...                         ...              ...         ...
# ...

# %%
Monthly_sales = dfa.groupby('Month').Sales.sum()
Monthly_sales
# Out:
# Month
# 4    3384047.56
# 5      10559.29
# Name: Sales, dtype: float64

# %%
city_sales=dfa.City.value_counts()
city_sales
# Out:
# City
# San Francisco    4434
# Los Angeles      3021
# New York City    2429
# Boston           1915
# Atlanta          1470
# Seattle          1440
# Dallas           1348
# Portland         1237
# Austin            973
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,6))
sns.countplot(x=dfa['City'])
plt.xlabel("City Name")
plt.ylabel("Number of Sells")
plt.title("city vs Sales")
# Out:
# Text(0.5, 1.0, 'city vs Sales')

# %%
dfa['Hour'] = dfa.Order_Date.dt.hour
# Out:
# /var/folders/d4/j7k55b31533djc626nh658gc0000gn/T/ipykernel_46225/819091554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Hour'] = dfa.Order_Date.dt.hour

# %%
dfa.groupby('Hour').count()
# Out:
#       order_ID  Product  Quantity_Ordered  Price_Each  Order_Date  \
# Hour
# 0          377      377               377         377         377
# 1          243      243               243         243         243
# 2          132      132               132         132         132
# 3           85       85                85          85          85
# 4           84       84                84          84          84
# 5          143      143               143         143         143
# 6          254      254               254         254         254
# 7          384      384               384         384         384
# 8          642      642               642         642         642
# 9          869      869               869         869         869
# 10        1133     1133              1133        1133        1133
# 11        1200     1200              1200        1200        1200
# 12        1199     1199              1199        1199        1199
# ...

# %%
hours =[hour for hour, dfa in dfa.groupby('Hour')]
plt.plot(hours, dfa.groupby('Hour').count())
plt.grid(True)
plt.xticks(hours)
plt.xlabel('Hours in 24 Hr Format')
plt.ylabel('Orders')
plt.show()

# %%
Highest_orders = dfa.Product.value_counts()
Highest_sales = dfa.groupby('Product').Sales.sum().sort_values(ascending=False)
fig, axes = plt.subplots(1, 2, figsize=(20,7))

sns.barplot(ax=axes[0], x=Highest_orders.index, y=Highest_orders.values)
axes[0].set_xlabel('Products')
axes[0].set_ylabel('No. of orders')
axes[0].tick_params(axis='x', rotation=90)

sns.barplot(ax=axes[1],x=Highest_sales.index, y=Highest_sales.values)
axes[1].set_xlabel('Products')
axes[1].set_ylabel('Sales Amount')
axes[1].tick_params(axis='x',rotation=90)

plt.show()
